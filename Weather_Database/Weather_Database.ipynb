# %%
#import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
#create a set of random lats and long combos
lats = np.random.uniform(low= -90, high= 90, size = 2000)
lngs = np.random.uniform(low= -180, high= 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
#Perform an API call 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold city info.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


for i, city in enumerate(cities):


    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | altoona
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | valparaiso
# Processing Record 6 of Set 1 | kastamonu
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | sampit
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | tiruvannamalai
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bosaso
# Processing Record 17 of Set 1 | antalaha
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | narsaq
# Processing Record 24 of Set 1 | saldanha
# Processing Record 25 of Set 1 | vanimo
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | airai
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | necochea
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | barra do garcas
# Processing Record 32 of Set 1 | pacific grove
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | kavieng
# Processing Record 35 of Set 1 | chermoz
# Processing Record 36 of Set 1 | seoul
# Processing Record 37 of Set 1 | nam tha
# City not found. Skipping...
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | lavrentiya
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | abu dhabi
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | bubaque
# Processing Record 47 of Set 1 | plettenberg bay
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | ahipara
# Processing Record 1 of Set 2 | falesti
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | cuamba
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | nome
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | barcelos
# Processing Record 9 of Set 2 | bonavista
# Processing Record 10 of Set 2 | raudeberg
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | thinadhoo
# Processing Record 13 of Set 2 | adilcevaz
# Processing Record 14 of Set 2 | leningradskiy
# Processing Record 15 of Set 2 | mubende
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | lorengau
# Processing Record 18 of Set 2 | constitucion
# Processing Record 19 of Set 2 | sesheke
# Processing Record 20 of Set 2 | nisia floresta
# Processing Record 21 of Set 2 | cayenne
# Processing Record 22 of Set 2 | yulara
# Processing Record 23 of Set 2 | opuwo
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | bafoulabe
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | araguatins
# City not found. Skipping...
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | ternate
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | klaksvik
# Processing Record 34 of Set 2 | bilibino
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 2 | arman
# Processing Record 38 of Set 2 | salym
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | cidreira
# Processing Record 42 of Set 2 | kindu
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | kalur kot
# Processing Record 46 of Set 2 | gospic
# Processing Record 47 of Set 2 | port augusta
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | nishihara
# Processing Record 50 of Set 2 | qasigiannguit
# Processing Record 1 of Set 3 | inongo
# Processing Record 2 of Set 3 | panzhihua
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | saint george
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | ambon
# Processing Record 7 of Set 3 | awbari
# Processing Record 8 of Set 3 | marica
# Processing Record 9 of Set 3 | praia
# Processing Record 10 of Set 3 | eureka
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | luba
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | roquetas de mar
# Processing Record 15 of Set 3 | emba
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | tiarei
# Processing Record 18 of Set 3 | tabarqah
# City not found. Skipping...
# Processing Record 19 of Set 3 | shelburne
# Processing Record 20 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | beringovskiy
# Processing Record 25 of Set 3 | fillmore
# Processing Record 26 of Set 3 | murray bridge
# Processing Record 27 of Set 3 | novikovo
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | gizo
# Processing Record 30 of Set 3 | krasnovka
# Processing Record 31 of Set 3 | khandbari
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | grindavik
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | mocuba
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | zambezi
# Processing Record 39 of Set 3 | sibolga
# Processing Record 40 of Set 3 | baghdad
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | yabrud
# Processing Record 43 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | nouadhibou
# Processing Record 46 of Set 3 | vostok
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | aklavik
# Processing Record 49 of Set 3 | mossendjo
# Processing Record 50 of Set 3 | chapais
# Processing Record 1 of Set 4 | dachau
# Processing Record 2 of Set 4 | avera
# Processing Record 3 of Set 4 | waitati
# Processing Record 4 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | gasa
# Processing Record 7 of Set 4 | ostrovnoy
# Processing Record 8 of Set 4 | sioux lookout
# Processing Record 9 of Set 4 | kiama
# Processing Record 10 of Set 4 | puerto madero
# Processing Record 11 of Set 4 | buon me thuot
# City not found. Skipping...
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | bilma
# Processing Record 14 of Set 4 | taltal
# Processing Record 15 of Set 4 | verkhoyansk
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | morondava
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | fairbanks
# Processing Record 21 of Set 4 | nador
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | nizwa
# Processing Record 24 of Set 4 | kulhudhuffushi
# Processing Record 25 of Set 4 | livenka
# Processing Record 26 of Set 4 | dunedin
# Processing Record 27 of Set 4 | guerrero negro
# Processing Record 28 of Set 4 | beloha
# Processing Record 29 of Set 4 | nantucket
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | pinawa
# Processing Record 32 of Set 4 | port macquarie
# Processing Record 33 of Set 4 | inhambane
# Processing Record 34 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 4 | sukumo
# Processing Record 36 of Set 4 | jahrom
# City not found. Skipping...
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | cherskiy
# Processing Record 39 of Set 4 | fortuna
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | zhezkazgan
# Processing Record 43 of Set 4 | celestun
# Processing Record 44 of Set 4 | port hedland
# Processing Record 45 of Set 4 | sept-iles
# Processing Record 46 of Set 4 | farrukhnagar
# Processing Record 47 of Set 4 | akita
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | perigueux
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | iwanai
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | tual
# Processing Record 4 of Set 5 | medicine hat
# Processing Record 5 of Set 5 | teacapan
# Processing Record 6 of Set 5 | la cruz
# Processing Record 7 of Set 5 | hithadhoo
# Processing Record 8 of Set 5 | blagoyevo
# Processing Record 9 of Set 5 | jardim
# Processing Record 10 of Set 5 | mizque
# Processing Record 11 of Set 5 | yangcun
# Processing Record 12 of Set 5 | mogadishu
# Processing Record 13 of Set 5 | kutum
# Processing Record 14 of Set 5 | mingshui
# Processing Record 15 of Set 5 | alta floresta
# Processing Record 16 of Set 5 | progreso
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | sao filipe
# Processing Record 19 of Set 5 | walvis bay
# Processing Record 20 of Set 5 | nyurba
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | sinegorye
# Processing Record 23 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 5 | touros
# Processing Record 25 of Set 5 | saint anthony
# Processing Record 26 of Set 5 | margate
# Processing Record 27 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 5 | chimore
# Processing Record 29 of Set 5 | towada
# Processing Record 30 of Set 5 | bandarbeyla
# Processing Record 31 of Set 5 | remuna
# Processing Record 32 of Set 5 | trairi
# Processing Record 33 of Set 5 | manzhouli
# Processing Record 34 of Set 5 | shingu
# Processing Record 35 of Set 5 | rodrigues alves
# Processing Record 36 of Set 5 | akdepe
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | mandalgovi
# Processing Record 39 of Set 5 | skjervoy
# Processing Record 40 of Set 5 | alberton
# Processing Record 41 of Set 5 | the pas
# Processing Record 42 of Set 5 | benguela
# Processing Record 43 of Set 5 | cape coast
# Processing Record 44 of Set 5 | pevek
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | korla
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | minas novas
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 50 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 6 | znamenskoye
# Processing Record 2 of Set 6 | brasilia
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | thunder bay
# Processing Record 5 of Set 6 | whitehorse
# Processing Record 6 of Set 6 | tateyama
# Processing Record 7 of Set 6 | sao sebastiao
# Processing Record 8 of Set 6 | ixtapa
# Processing Record 9 of Set 6 | cody
# Processing Record 10 of Set 6 | bethel
# Processing Record 11 of Set 6 | yamada
# Processing Record 12 of Set 6 | hambantota
# Processing Record 13 of Set 6 | esso
# Processing Record 14 of Set 6 | lagoa
# Processing Record 15 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | karla
# Processing Record 17 of Set 6 | pangnirtung
# Processing Record 18 of Set 6 | gwadar
# Processing Record 19 of Set 6 | agva
# City not found. Skipping...
# Processing Record 20 of Set 6 | tocopilla
# Processing Record 21 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 6 | severo-kurilsk
# Processing Record 24 of Set 6 | tempio pausania
# Processing Record 25 of Set 6 | witu
# Processing Record 26 of Set 6 | westport
# Processing Record 27 of Set 6 | katherine
# Processing Record 28 of Set 6 | iqaluit
# Processing Record 29 of Set 6 | rivadavia
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | ponta delgada
# Processing Record 32 of Set 6 | lamar
# Processing Record 33 of Set 6 | lunca
# Processing Record 34 of Set 6 | caravelas
# Processing Record 35 of Set 6 | preston
# Processing Record 36 of Set 6 | santa rosa
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | srednekolymsk
# Processing Record 39 of Set 6 | tezu
# Processing Record 40 of Set 6 | ndola
# Processing Record 41 of Set 6 | birao
# Processing Record 42 of Set 6 | ola
# Processing Record 43 of Set 6 | zhigansk
# Processing Record 44 of Set 6 | lasa
# Processing Record 45 of Set 6 | chokwe
# Processing Record 46 of Set 6 | richards bay
# Processing Record 47 of Set 6 | omsukchan
# Processing Record 48 of Set 6 | copiapo
# Processing Record 49 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 50 of Set 6 | vao
# Processing Record 1 of Set 7 | huntington
# Processing Record 2 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 7 | zeya
# Processing Record 4 of Set 7 | mamallapuram
# Processing Record 5 of Set 7 | veraval
# Processing Record 6 of Set 7 | cockburn town
# Processing Record 7 of Set 7 | buraydah
# Processing Record 8 of Set 7 | asau
# Processing Record 9 of Set 7 | agadir
# Processing Record 10 of Set 7 | atasu
# Processing Record 11 of Set 7 | kunming
# Processing Record 12 of Set 7 | chabahar
# Processing Record 13 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 7 | pangody
# Processing Record 15 of Set 7 | grand gaube
# Processing Record 16 of Set 7 | dickinson
# Processing Record 17 of Set 7 | gallup
# Processing Record 18 of Set 7 | tiksi
# Processing Record 19 of Set 7 | plattsburgh
# Processing Record 20 of Set 7 | kyaukse
# Processing Record 21 of Set 7 | ponta do sol
# Processing Record 22 of Set 7 | padang
# Processing Record 23 of Set 7 | christchurch
# Processing Record 24 of Set 7 | mixtequilla
# City not found. Skipping...
# Processing Record 25 of Set 7 | havoysund
# Processing Record 26 of Set 7 | ulladulla
# Processing Record 27 of Set 7 | marawi
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | teguise
# Processing Record 30 of Set 7 | matara
# Processing Record 31 of Set 7 | faanui
# Processing Record 32 of Set 7 | dali
# Processing Record 33 of Set 7 | bundaberg
# Processing Record 34 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 7 | abha
# Processing Record 36 of Set 7 | tuatapere
# Processing Record 37 of Set 7 | hofn
# Processing Record 38 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 7 | ornskoldsvik
# Processing Record 40 of Set 7 | hendersonville
# Processing Record 41 of Set 7 | vana-voidu
# City not found. Skipping...
# Processing Record 42 of Set 7 | saint-avold
# Processing Record 43 of Set 7 | mana
# Processing Record 44 of Set 7 | half moon bay
# Processing Record 45 of Set 7 | amahai
# Processing Record 46 of Set 7 | balingasay
# Processing Record 47 of Set 7 | chengde
# Processing Record 48 of Set 7 | nouakchott
# Processing Record 49 of Set 7 | illela
# Processing Record 50 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | okmulgee
# Processing Record 2 of Set 8 | farafangana
# Processing Record 3 of Set 8 | neryungri
# Processing Record 4 of Set 8 | pochutla
# Processing Record 5 of Set 8 | southbridge
# Processing Record 6 of Set 8 | shellbrook
# Processing Record 7 of Set 8 | kahului
# Processing Record 8 of Set 8 | shibetsu
# Processing Record 9 of Set 8 | tanout
# Processing Record 10 of Set 8 | daru
# Processing Record 11 of Set 8 | zeerust
# Processing Record 12 of Set 8 | lodwar
# Processing Record 13 of Set 8 | florianopolis
# Processing Record 14 of Set 8 | kununurra
# Processing Record 15 of Set 8 | dhidhdhoo
# Processing Record 16 of Set 8 | bani
# Processing Record 17 of Set 8 | biak
# Processing Record 18 of Set 8 | santa cruz cabralia
# Processing Record 19 of Set 8 | irbil
# Processing Record 20 of Set 8 | camacha
# Processing Record 21 of Set 8 | zhangjiakou
# Processing Record 22 of Set 8 | ouesso
# Processing Record 23 of Set 8 | gamba
# Processing Record 24 of Set 8 | haines junction
# Processing Record 25 of Set 8 | borodyanka
# Processing Record 26 of Set 8 | la union
# Processing Record 27 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 28 of Set 8 | muyuka
# Processing Record 29 of Set 8 | mushie
# Processing Record 30 of Set 8 | broome
# Processing Record 31 of Set 8 | muros
# Processing Record 32 of Set 8 | atar
# Processing Record 33 of Set 8 | nabire
# Processing Record 34 of Set 8 | chistoye
# Processing Record 35 of Set 8 | havre
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | hatillo
# Processing Record 38 of Set 8 | geraldton
# Processing Record 39 of Set 8 | abalak
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | hami
# Processing Record 42 of Set 8 | norman wells
# Processing Record 43 of Set 8 | nieuw amsterdam
# Processing Record 44 of Set 8 | stornoway
# Processing Record 45 of Set 8 | chau doc
# Processing Record 46 of Set 8 | suez
# Processing Record 47 of Set 8 | hvide sande
# Processing Record 48 of Set 8 | balfron
# Processing Record 49 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 8 | college
# Processing Record 1 of Set 9 | tomaszow mazowiecki
# Processing Record 2 of Set 9 | wanlaweyn
# Processing Record 3 of Set 9 | bambanglipuro
# Processing Record 4 of Set 9 | te anau
# Processing Record 5 of Set 9 | nizhniy kuranakh
# Processing Record 6 of Set 9 | sohag
# Processing Record 7 of Set 9 | chimbote
# Processing Record 8 of Set 9 | sambava
# Processing Record 9 of Set 9 | hualmay
# Processing Record 10 of Set 9 | ibra
# Processing Record 11 of Set 9 | mochudi
# Processing Record 12 of Set 9 | kharp
# Processing Record 13 of Set 9 | beisfjord
# Processing Record 14 of Set 9 | qinhuangdao
# Processing Record 15 of Set 9 | caracollo
# Processing Record 16 of Set 9 | hamilton
# Processing Record 17 of Set 9 | kosa
# Processing Record 18 of Set 9 | tautira
# Processing Record 19 of Set 9 | tura
# Processing Record 20 of Set 9 | coihaique
# Processing Record 21 of Set 9 | berbera
# Processing Record 22 of Set 9 | nacala
# Processing Record 23 of Set 9 | bathsheba
# Processing Record 24 of Set 9 | alofi
# Processing Record 25 of Set 9 | bhadasar
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | santa isabel do rio negro
# Processing Record 28 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 9 | malinyi
# Processing Record 30 of Set 9 | banda aceh
# Processing Record 31 of Set 9 | chake chake
# Processing Record 32 of Set 9 | vredendal
# Processing Record 33 of Set 9 | hay river
# Processing Record 34 of Set 9 | auki
# Processing Record 35 of Set 9 | linqiong
# Processing Record 36 of Set 9 | natal
# Processing Record 37 of Set 9 | feltre
# Processing Record 38 of Set 9 | loandjili
# Processing Record 39 of Set 9 | jishu
# Processing Record 40 of Set 9 | tukrah
# Processing Record 41 of Set 9 | mizdah
# Processing Record 42 of Set 9 | gillette
# Processing Record 43 of Set 9 | saint-leu
# Processing Record 44 of Set 9 | waingapu
# Processing Record 45 of Set 9 | kalabo
# Processing Record 46 of Set 9 | nicoya
# Processing Record 47 of Set 9 | sterling
# Processing Record 48 of Set 9 | mareeba
# Processing Record 49 of Set 9 | mehamn
# Processing Record 50 of Set 9 | magadan
# Processing Record 1 of Set 10 | juneau
# Processing Record 2 of Set 10 | lazaro cardenas
# Processing Record 3 of Set 10 | olden
# Processing Record 4 of Set 10 | tagusao
# Processing Record 5 of Set 10 | presidente medici
# Processing Record 6 of Set 10 | yambio
# Processing Record 7 of Set 10 | valverde del camino
# Processing Record 8 of Set 10 | santa maria
# Processing Record 9 of Set 10 | roma
# Processing Record 10 of Set 10 | orneta
# Processing Record 11 of Set 10 | tessalit
# Processing Record 12 of Set 10 | meulaboh
# Processing Record 13 of Set 10 | sebring
# Processing Record 14 of Set 10 | maarianhamina
# Processing Record 15 of Set 10 | chuy
# Processing Record 16 of Set 10 | bar harbor
# Processing Record 17 of Set 10 | fomboni
# Processing Record 18 of Set 10 | cabinda
# Processing Record 19 of Set 10 | viedma
# Processing Record 20 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 10 | krasnogvardeyskiy
# Processing Record 22 of Set 10 | aitape
# Processing Record 23 of Set 10 | yumen
# Processing Record 24 of Set 10 | nynashamn
# Processing Record 25 of Set 10 | alamosa
# Processing Record 26 of Set 10 | lompoc
# Processing Record 27 of Set 10 | muravlenko
# Processing Record 28 of Set 10 | jijiga
# Processing Record 29 of Set 10 | saint-augustin
# Processing Record 30 of Set 10 | dunblane
# Processing Record 31 of Set 10 | evensk
# Processing Record 32 of Set 10 | ajdabiya
# Processing Record 33 of Set 10 | baruun-urt
# Processing Record 34 of Set 10 | odweyne
# Processing Record 35 of Set 10 | hirara
# Processing Record 36 of Set 10 | noyabrsk
# Processing Record 37 of Set 10 | galesong
# Processing Record 38 of Set 10 | kovdor
# Processing Record 39 of Set 10 | sainte-marie
# Processing Record 40 of Set 10 | olafsvik
# Processing Record 41 of Set 10 | solenzo
# Processing Record 42 of Set 10 | ghanzi
# Processing Record 43 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 10 | hukuntsi
# Processing Record 45 of Set 10 | shache
# Processing Record 46 of Set 10 | camana
# Processing Record 47 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 10 | yeppoon
# Processing Record 49 of Set 10 | gemena
# Processing Record 50 of Set 10 | lakes entrance
# Processing Record 1 of Set 11 | demmin
# Processing Record 2 of Set 11 | iskele
# Processing Record 3 of Set 11 | kortkeros
# Processing Record 4 of Set 11 | shakawe
# Processing Record 5 of Set 11 | smolenka
# Processing Record 6 of Set 11 | flinders
# Processing Record 7 of Set 11 | kirovskiy
# Processing Record 8 of Set 11 | puerto escondido
# Processing Record 9 of Set 11 | pilar
# Processing Record 10 of Set 11 | point fortin
# Processing Record 11 of Set 11 | iskateley
# Processing Record 12 of Set 11 | suntar
# Processing Record 13 of Set 11 | praya
# Processing Record 14 of Set 11 | tabas
# Processing Record 15 of Set 11 | san mateo del mar
# Processing Record 16 of Set 11 | juegang
# Processing Record 17 of Set 11 | haukipudas
# Processing Record 18 of Set 11 | quesnel
# Processing Record 19 of Set 11 | fort nelson
# Processing Record 20 of Set 11 | safaga
# Processing Record 21 of Set 11 | abonnema
# Processing Record 22 of Set 11 | aykhal
# Processing Record 23 of Set 11 | brandon
# Processing Record 24 of Set 11 | malangwa
# Processing Record 25 of Set 11 | vattalkundu
# Processing Record 26 of Set 11 | chateaubelair
# Processing Record 27 of Set 11 | general roca
# Processing Record 28 of Set 11 | karratha
# Processing Record 29 of Set 11 | luzilandia
# Processing Record 30 of Set 11 | libreville
# Processing Record 31 of Set 11 | yichun
# Processing Record 32 of Set 11 | sauda
# Processing Record 33 of Set 11 | carballo
# Processing Record 34 of Set 11 | sydney
# Processing Record 35 of Set 11 | lata
# Processing Record 36 of Set 11 | hobyo
# Processing Record 37 of Set 11 | onega
# Processing Record 38 of Set 11 | wajima
# Processing Record 39 of Set 11 | qaqortoq
# Processing Record 40 of Set 11 | riyadh
# Processing Record 41 of Set 11 | ochakiv
# Processing Record 42 of Set 11 | atherton
# Processing Record 43 of Set 11 | portland
# Processing Record 44 of Set 11 | vila do maio
# Processing Record 45 of Set 11 | umarkot
# Processing Record 46 of Set 11 | naryan-mar
# Processing Record 47 of Set 11 | naze
# Processing Record 48 of Set 11 | podosinovets
# Processing Record 49 of Set 11 | kichera
# Processing Record 50 of Set 11 | deer lake
# Processing Record 1 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 12 | kraslava
# Processing Record 3 of Set 12 | lusambo
# Processing Record 4 of Set 12 | danville
# Processing Record 5 of Set 12 | zyryanka
# Processing Record 6 of Set 12 | dingle
# Processing Record 7 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 8 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 9 of Set 12 | mayskiy
# Processing Record 10 of Set 12 | tommot
# Processing Record 11 of Set 12 | lucapa
# Processing Record 12 of Set 12 | tongliao
# Processing Record 13 of Set 12 | saquena
# Processing Record 14 of Set 12 | mackay
# Processing Record 15 of Set 12 | maniitsoq
# Processing Record 16 of Set 12 | canto do buriti
# Processing Record 17 of Set 12 | musoma
# Processing Record 18 of Set 12 | khlung
# Processing Record 19 of Set 12 | neiafu
# Processing Record 20 of Set 12 | vestmanna
# Processing Record 21 of Set 12 | seydi
# Processing Record 22 of Set 12 | saint-gaudens
# Processing Record 23 of Set 12 | vila
# Processing Record 24 of Set 12 | matongo
# Processing Record 25 of Set 12 | dolzhanskaya
# Processing Record 26 of Set 12 | roald
# Processing Record 27 of Set 12 | iracoubo
# Processing Record 28 of Set 12 | ozernovskiy
# Processing Record 29 of Set 12 | suzun
# Processing Record 30 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 31 of Set 12 | salalah
# Processing Record 32 of Set 12 | wanaka
# Processing Record 33 of Set 12 | deputatskiy
# Processing Record 34 of Set 12 | axim
# Processing Record 35 of Set 12 | pegnitz
# Processing Record 36 of Set 12 | cedar city
# Processing Record 37 of Set 12 | okhotsk
# Processing Record 38 of Set 12 | kirakira
# Processing Record 39 of Set 12 | moorhead
# Processing Record 40 of Set 12 | dudinka
# Processing Record 41 of Set 12 | mantua
# Processing Record 42 of Set 12 | saint-pierre
# Processing Record 43 of Set 12 | idlib
# Processing Record 44 of Set 12 | kuching
# Processing Record 45 of Set 12 | faya
# Processing Record 46 of Set 12 | san luis
# Processing Record 47 of Set 12 | poso
# Processing Record 48 of Set 12 | gogrial
# Processing Record 49 of Set 12 | port-cartier
# Processing Record 50 of Set 12 | sombor
# Processing Record 1 of Set 13 | murdochville
# Processing Record 2 of Set 13 | nalgonda
# Processing Record 3 of Set 13 | warrington
# Processing Record 4 of Set 13 | costinesti
# Processing Record 5 of Set 13 | kaita
# Processing Record 6 of Set 13 | mahibadhoo
# Processing Record 7 of Set 13 | mangrol
# Processing Record 8 of Set 13 | rabat
# Processing Record 9 of Set 13 | bluefields
# Processing Record 10 of Set 13 | abeche
# Processing Record 11 of Set 13 | aswan
# Processing Record 12 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 13 | bull savanna
# Processing Record 14 of Set 13 | pijijiapan
# Processing Record 15 of Set 13 | batagay
# Processing Record 16 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 13 | fukue
# Processing Record 18 of Set 13 | la ronge
# Processing Record 19 of Set 13 | nancha
# Processing Record 20 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 13 | port hardy
# Processing Record 22 of Set 13 | rafraf
# Processing Record 23 of Set 13 | nara
# Processing Record 24 of Set 13 | acaponeta
# Processing Record 25 of Set 13 | kushima
# Processing Record 26 of Set 13 | kapiri mposhi
# Processing Record 27 of Set 13 | belmonte
# Processing Record 28 of Set 13 | gornopravdinsk
# Processing Record 29 of Set 13 | puerto ayacucho
# Processing Record 30 of Set 13 | novyy urengoy
# Processing Record 31 of Set 13 | coahuayana
# Processing Record 32 of Set 13 | obihiro
# Processing Record 33 of Set 13 | sao joao da barra
# Processing Record 34 of Set 13 | ayr
# Processing Record 35 of Set 13 | zhob
# Processing Record 36 of Set 13 | ellington
# Processing Record 37 of Set 13 | klichka
# Processing Record 38 of Set 13 | morros
# Processing Record 39 of Set 13 | eresos
# Processing Record 40 of Set 13 | voh
# Processing Record 41 of Set 13 | killarney
# Processing Record 42 of Set 13 | labuhan
# Processing Record 43 of Set 13 | bara
# Processing Record 44 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 45 of Set 13 | roebourne
# Processing Record 46 of Set 13 | hasanabad
# Processing Record 47 of Set 13 | berlevag
# Processing Record 48 of Set 13 | kudahuvadhoo
# Processing Record 49 of Set 13 | dire
# Processing Record 50 of Set 13 | sinnamary
# Processing Record 1 of Set 14 | portoferraio
# Processing Record 2 of Set 14 | haizhou
# Processing Record 3 of Set 14 | brae
# Processing Record 4 of Set 14 | khingansk
# Processing Record 5 of Set 14 | cartagena
# Processing Record 6 of Set 14 | lamas
# Processing Record 7 of Set 14 | ambagarh chauki
# Processing Record 8 of Set 14 | baillif
# Processing Record 9 of Set 14 | yuli
# Processing Record 10 of Set 14 | sakaraha
# Processing Record 11 of Set 14 | san jeronimo
# Processing Record 12 of Set 14 | kiruna
# Processing Record 13 of Set 14 | tengushevo
# Processing Record 14 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 14 | kruisfontein
# Processing Record 16 of Set 14 | burnie
# Processing Record 17 of Set 14 | ridgecrest
# Processing Record 18 of Set 14 | yerbogachen
# Processing Record 19 of Set 14 | phan thiet
# Processing Record 20 of Set 14 | verkhnyaya toyma
# Processing Record 21 of Set 14 | wellington
# Processing Record 22 of Set 14 | kwakoa
# Processing Record 23 of Set 14 | nortelandia
# Processing Record 24 of Set 14 | kawalu
# Processing Record 25 of Set 14 | bud
# Processing Record 26 of Set 14 | arys
# Processing Record 27 of Set 14 | shkotovo-26
# City not found. Skipping...
# Processing Record 28 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 29 of Set 14 | ketchikan
# Processing Record 30 of Set 14 | safranbolu
# Processing Record 31 of Set 14 | buala
# Processing Record 32 of Set 14 | suba
# Processing Record 33 of Set 14 | krasnaya polyana
# Processing Record 34 of Set 14 | zhangzhou
# Processing Record 35 of Set 14 | champagnole
# Processing Record 36 of Set 14 | kotma
# Processing Record 37 of Set 14 | kedarnath
# City not found. Skipping...
# Processing Record 38 of Set 14 | kloulklubed
# Processing Record 39 of Set 14 | carutapera
# Processing Record 40 of Set 14 | bemidji
# Processing Record 41 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 14 | panaba
# Processing Record 43 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 44 of Set 14 | isangel
# Processing Record 45 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 14 | tramagal
# Processing Record 47 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 48 of Set 14 | pativilca
# Processing Record 49 of Set 14 | skibbereen
# Processing Record 50 of Set 14 | outjo
# Processing Record 1 of Set 15 | zabol
# Processing Record 2 of Set 15 | lethem
# Processing Record 3 of Set 15 | bereda
# Processing Record 4 of Set 15 | northam
# Processing Record 5 of Set 15 | chiang khong
# Processing Record 6 of Set 15 | manavalakurichi
# Processing Record 7 of Set 15 | huizen
# Processing Record 8 of Set 15 | haimen
# Processing Record 9 of Set 15 | gribanovskiy
# Processing Record 10 of Set 15 | wenzhou
# Processing Record 11 of Set 15 | zhanaozen
# Processing Record 12 of Set 15 | rocha
# Processing Record 13 of Set 15 | tecoanapa
# Processing Record 14 of Set 15 | sabla
# Processing Record 15 of Set 15 | eyl
# Processing Record 16 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 18 of Set 15 | maunabo
# Processing Record 19 of Set 15 | novopavlovka
# Processing Record 20 of Set 15 | denpasar
# Processing Record 21 of Set 15 | kuminskiy
# Processing Record 22 of Set 15 | salina
# Processing Record 23 of Set 15 | mweka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dicitionaires to a Pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Altoona      US  40.5187  -78.3947     88.81        59          39
# 1           Barrow      US  71.2906 -156.7887     44.62        87          90
# 2        Upernavik      GL  72.7868  -56.1549     41.25        81          12
# 3           Kodiak      US  57.7900 -152.4072     51.31        87          90
# 4       Valparaiso      CL -33.0393  -71.6273     58.64        82          90
# 5        Kastamonu      TR  41.5000   33.6667     56.07        82           0
# 6           Atuona      PF  -9.8000 -139.0333     77.97        69          68
# 7           Sampit      ID  -2.5333  112.9500     70.36        97           2
# 8  Bambous Virieux      MU -20.3428   57.7575     70.05        64          20
# 9        Busselton      AU -33.6500  115.3333     58.08        65           8
#
#    Wind Speed Current Description
# 0        1.01    scattered clouds
# 1       10.36     overcast clouds
# 2       13.24          few clouds
# 3        6.91                 fog
# 4        6.91             drizzle
# 5        4.09           clear sky
# 6       22.95       broken clouds
# 7        2.44           clear sky
# 8       12.66          few clouds
# 9       20.58           clear sky

# %%
#create the output file (csv).
output_data_file = "Weather_database.csv"
#export the city-data into a CSV
city_data_df.to_csv(output_data_file)
